# %% [markdown]
# # Exercises 2

# %% [markdown]
# - Import the necessary matplotlib module for plotting
# - Import the data module of skimage
# - Using dir() find a picture of the moon contained in skimage.data
# - Load that image
# - Using matplotlib plot that picture
# - Try to change the color map of the picture to 'viridis'
# - Superpose a gray scale and 'viridis' image on top of each other
# - Change the size of that image

# %%
import matplotlib.pyplot as plt
import skimage.data

# %%
for i in dir(skimage.data):
    if 'moon' in i:
        print(i)
# Out:
# moon

# %%
plt.imshow(skimage.data.moon(), cmap='viridis')

# %% [markdown]
# # Solutions 2

# %%
import matplotlib.pyplot as plt

# %%
import skimage.data

# %%
dir(skimage.data)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_binary_blobs',
#  '_np',
#  '_os',
#  'astronaut',
#  'binary_blobs',
#  'camera',
#  'checkerboard',
#  'chelsea',
#  'clock',
#  'coffee',
#  'coins',
#  'data_dir',
#  'expected_warnings',
#  'horse',
#  'hubble_deep_field',
#  'img_as_bool',
#  'immunohistochemistry',
#  'imread',
#  'lfw_subset',
#  'load',
#  'logo',
#  'moon',
#  'osp',
#  'page',
#  'rocket',
#  'stereo_motorcycle',
#  'text',
#  'use_plugin',
#  'warn']

# %%
image = skimage.data.moon()

# %%
plt.imshow(image)
plt.show()

# %%
plt.imshow(image, cmap = 'jet')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(image, cmap = 'gray')
plt.imshow(image, cmap = 'jet', alpha = 0.3)
plt.show()
